# %%
#read file
import pandas as pd
pd.read_csv('landingcompany.csv')
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0     1-6-18     East   Martha  Alexander    Television   95.0    1,198.00
# 1    1-23-18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2     2-9-18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3    2-26-18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4    3-15-18     West  Timothy    Stephen    Television   56.0    1,198.00
# 5     4-1-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 6    4-18-18  Central   Martha     Steven    Television   75.0    1,198.00
# 7     5-5-18  Central  Hermann       Luis    Television   90.0    1,198.00
# 8    5-22-18     West  Douglas    Michael    Television   32.0    1,198.00
# 9     6-8-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 10   6-25-18  Central  Hermann      Sigal    Television   90.0    1,198.00
# ...

# %%
#head method
import pandas as pd
data = pd.read_csv('landingcompany.csv')
data = data.copy()
data.head()
# Out:
#   OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0    1-6-18     East   Martha  Alexander    Television   95.0    1,198.00
# 1   1-23-18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2    2-9-18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3   2-26-18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4   3-15-18     West  Timothy    Stephen    Television   56.0    1,198.00
#
#        Sale_amt
# 0   113,810.00
# 1    25,000.00
# 2    43,128.00
# 3     6,075.00
# 4    67,088.00

# %%
#tail method

data.tail()
# Out:
#    OrderDate   Region  Manager SalesMan          Item  Units  Unit_price   \
# 40  11-17-19  Central  Hermann     Luis  Home Theater   11.0      500.00
# 41   12-4-19  Central  Hermann     Luis  Home Theater   94.0      500.00
# 42  12-21-19  Central   Martha   Steven  Home Theater   28.0      500.00
# 43       NaN      NaN      NaN      NaN           NaN    NaN          NaN
# 44       NaN      NaN      NaN      NaN           NaN    NaN          NaN
#
#        Sale_amt
# 40    5,500.00
# 41   47,000.00
# 42   14,000.00
# 43          NaN
# 44          NaN

# %%
#isnull
data.isnull().sum()
# Out:
# OrderDate       2
# Region          2
# Manager         2
# SalesMan        2
# Item            2
# Units           2
#  Unit_price     2
# Sale_amt        2
# dtype: int64

# %%
data.drop(3)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0     1-6-18     East   Martha  Alexander    Television   95.0    1,198.00
# 1    1-23-18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2     2-9-18  Central  Hermann       Luis    Television   36.0    1,198.00
# 4    3-15-18     West  Timothy    Stephen    Television   56.0    1,198.00
# 5     4-1-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 6    4-18-18  Central   Martha     Steven    Television   75.0    1,198.00
# 7     5-5-18  Central  Hermann       Luis    Television   90.0    1,198.00
# 8    5-22-18     West  Douglas    Michael    Television   32.0    1,198.00
# 9     6-8-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 10   6-25-18  Central  Hermann      Sigal    Television   90.0    1,198.00
# 11   7-12-18     East   Martha      Diana  Home Theater   29.0      500.00
# ...

# %%
data.shape
# Out:
# (45, 8)

# %%
print(data.duplicated().sum())
# Out:
# 1

# %%
import pandas as pd
data= pd.read_csv (r'C:\Users\RDP-1\Downloads\nithes fire mass pandas\landingcompany.csv')
data.to_json (r'C:\Users\RDP-1\Downloads\nithes fire mass pandas\new_landingcompany.json')

# %%
import pandas as pd
pd.read_json('new_landingcompany.json')
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0     1-6-18     East   Martha  Alexander    Television   95.0    1,198.00
# 1    1-23-18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2     2-9-18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3    2-26-18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4    3-15-18     West  Timothy    Stephen    Television   56.0    1,198.00
# 5     4-1-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 6    4-18-18  Central   Martha     Steven    Television   75.0    1,198.00
# 7     5-5-18  Central  Hermann       Luis    Television   90.0    1,198.00
# 8    5-22-18     West  Douglas    Michael    Television   32.0    1,198.00
# 9     6-8-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 10   6-25-18  Central  Hermann      Sigal    Television   90.0    1,198.00
# ...

# %%
data = data.dropna(how='any',axis=0)

# %%
data.isnull().sum()
# Out:
# OrderDate       0
# Region          0
# Manager         0
# SalesMan        0
# Item            0
# Units           0
#  Unit_price     0
# Sale_amt        0
# dtype: int64

# %%
data.drop_duplicates(keep=False)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0     1-6-18     East   Martha  Alexander    Television   95.0    1,198.00
# 1    1-23-18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2     2-9-18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3    2-26-18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4    3-15-18     West  Timothy    Stephen    Television   56.0    1,198.00
# 5     4-1-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 6    4-18-18  Central   Martha     Steven    Television   75.0    1,198.00
# 7     5-5-18  Central  Hermann       Luis    Television   90.0    1,198.00
# 8    5-22-18     West  Douglas    Michael    Television   32.0    1,198.00
# 9     6-8-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 10   6-25-18  Central  Hermann      Sigal    Television   90.0    1,198.00
# ...

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data = pd.DataFrame(columns=('Time','age','country'))

# %%
import pandas as pd
df= pd.read_csv('landingcompany.csv')
data = {
    "OrderDate":["14-22-19"], 
    "Region":   ["West"], 
    "Manager":  ["jack"],  
    "SalesMan": ["nick"],
    "Item":     ["Laptop"],
    "Units" :   [70.5],
    "Unit_price":[3,45,000],
    "Sale_amt" :[55,000.00],
    
}

# %%
print(df)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0     1-6-18     East   Martha  Alexander    Television   95.0    1,198.00
# 1    1-23-18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2     2-9-18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3    2-26-18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4    3-15-18     West  Timothy    Stephen    Television   56.0    1,198.00
# 5     4-1-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 6    4-18-18  Central   Martha     Steven    Television   75.0    1,198.00
# 7     5-5-18  Central  Hermann       Luis    Television   90.0    1,198.00
# 8    5-22-18     West  Douglas    Michael    Television   32.0    1,198.00
# 9     6-8-18     East   Martha  Alexander  Home Theater   60.0      500.00
# 10   6-25-18  Central  Hermann      Sigal    Television   90.0    1,198.00
# ...

# %%
len(data)
# Out:
# 8

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqldb://username:password@localhost/data')

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://username:password@localhost/data')

# %%
import pandas as pd
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 24, 35, 32],
        'City': ['New York', 'Paris', 'Berlin', 'London']}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   24     Paris
# 2  Peter   35    Berlin
# 3  Linda   32    London

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('People', con=engine, if_exists='replace', index=False)
# Out:
# 4

# %%
result_df = pd.read_sql('People', con=engine)
print(result_df)
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   24     Paris
# 2  Peter   35    Berlin
# 3  Linda   32    London
